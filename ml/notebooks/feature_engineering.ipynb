# %%
import pandas as pd

# %%
df = pd.read_csv("/content/incidents_cleaned.csv")
df.head()
# Out:
#    event_date violence_type  fatalities  civilian_deaths  latitude  longitude  \
# 0  2010-02-01   state_based           0                0  12.00000  11.500000
# 1  2010-06-25   state_based           0                0  11.50000   8.500000
# 2  2010-08-13   state_based           3                0  11.84644  13.160274
# 3  2010-08-25   state_based           2                0  11.84644  13.160274
# 4  2010-08-25   state_based           0                0  11.74700  11.960800
#
#    country    state_raw        lga_raw
# 0  Nigeria   Yobe state            NaN
# 1  Nigeria          NaN            NaN
# 2  Nigeria  Borno state  Maiduguri lga
# 3  Nigeria  Borno state  Maiduguri lga
# 4  Nigeria   Yobe state   Damaturu lga

# %%
df.shape
# Out:
# (6875, 9)
